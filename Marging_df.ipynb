# %%
import pandas as pd
import os

csv1=r"C:\Users\User\Desktop\project in data science\CrawlingCsv\crawling_1.csv"
csv2=r"C:\Users\User\Desktop\project in data science\CrawlingCsv\crawling_2.csv"
csv3=r"C:\Users\User\Desktop\project in data science\CrawlingCsv\crawling_3.csv"
df1=pd.read_csv(r"C:\Users\User\Desktop\project in data science\CrawlingCsv\crawling_1.csv")
df2=pd.read_csv(r"C:\Users\User\Desktop\project in data science\CrawlingCsv\crawling_2.csv")
df3=pd.read_csv(r"C:\Users\User\Desktop\project in data science\CrawlingCsv\crawling_3.csv")

# %%
df1
# Out:
#                  Unnamed: 0       Belarus      Mongolia        Russia  \
# 0                   Alcohol  11247.529167   6372.340102  1.885327e+05
# 1               All Cancers   1498.662628    577.962527  2.199232e+04
# 2     Alzheimers & Dementia      0.000000      0.000000  0.000000e+00
# 3                    Anemia     68.035126    197.680887  1.050728e+03
# 4                    Asthma     37.797292     97.037384  8.172330e+02
# 5              Birth Trauma    160.638491     34.094216  3.517021e+03
# 6            Bladder Cancer  63902.936652  34816.751116  1.061629e+06
# 7                       NaN    137.960116    309.142747  5.355795e+03
# 8             Breast Cancer    208.830038    206.532270  5.312014e+03
# 9           Cervical Cancer   1611.109571    145.228247  2.415215e+04
# 10     Colon-Rectum Cancers    269.305706    188.173846  5.166080e+03
# 11     Congenital Anomalies  26680.163491   9304.442678  2.984360e+05
# ...

# %%
df2
# Out:
#                            Unnamed: 0         Venezuela        Saudi Arabia  \
# 0              Military Expenditures         13933.6106        305665.78738
# 1   Electricity by Renewable Sources                0.0                 0.0
# 2      Urban Population Growth Rates             0.0128              0.0217
# 3             Infant Mortality Rates        63213.09462        43795.849718
# 4             Freight Traffic by Air   44075707000000.0  3.778941255437e+16
# ..                                ...               ...                 ...
# 70                        Population         32,605,000          34,825,000
# 71                 Crude Oil Exports          1,656,000           7,341,000
# 72                  Young Population              0.257               0.248
# 73                   HIV/AIDS Deaths                NaN                 500
# 74                Physicians Density                NaN         83205.15169
#
# ...

# %%
df3
# Out:
#                                            Unnamed: 0   China   India  \
# 0                                      Deaths per Day  30,373  28,279
# 1                                     Life Expectancy    77.3   70.19
# 2                    World Countries by National Debt  57.24%  75.11%
# 3                               Crime Rate by Country   30.14   44.43
# 4               Most Dangerous Countries in the World   2.217   2.605
# ..                                                ...     ...     ...
# 136                              Sanctioned Countries     NaN     NaN
# 137                                Tax-Free Countries     NaN     NaN
# 138                     Traditional Economy Countries     NaN     NaN
# 139  EFTA Countries | European Free Trade Association     NaN     NaN
# 140                   Countries Without Central Banks     NaN     NaN
#
#     United States Nigeria  Russia Indonesia Pakistan  Brazil    Japan  ...  \
# ...

# %%
df = pd.concat(map(pd.read_csv, [csv1, csv2,csv3]), ignore_index=True)
df.to_csv('Not_cleand.csv', encoding='utf-8')
df
# Out:
#                                            Unnamed: 0  Belarus Mongolia  \
# 0                                             Alcohol  11247.5  6372.34
# 1                                         All Cancers  1498.66  577.963
# 2                               Alzheimers & Dementia        0        0
# 3                                              Anemia  68.0351  197.681
# 4                                              Asthma  37.7973  97.0374
# ..                                                ...      ...      ...
# 263                              Sanctioned Countries      NaN      NaN
# 264                                Tax-Free Countries      NaN      NaN
# 265                     Traditional Economy Countries      NaN      NaN
# 266  EFTA Countries | European Free Trade Association      NaN      NaN
# 267                   Countries Without Central Banks      NaN      NaN
#
#       Russia Guatemala  Slovenia El Salvador  Ukraine   Poland   Latvia  ...  \
# ...
